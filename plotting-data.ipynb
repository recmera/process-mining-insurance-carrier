# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib notebook

# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np
import scipy

# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_csv("log_claims_2021.csv", sep=";")
display(df.head(10))
# Out:
#    claim_id  activity_instance                   activity      Inicio  \
# 0         1              10000                   Accident  01-01-2008
# 1         1              10001                 File Claim  09-01-2008
# 2         1              10002             Check Contract  12-01-2008
# 3         1              10003                 Franchise?  13-01-2008
# 4         1              10004                   Covered?  15-01-2008
# 5         1              10005        Acceptance Decision  20-01-2008
# 6         1              10006        Start Investigation  01-02-2008
# 7         1              10007             Appoint Lawyer  10-02-2008
# 8         1              10008             Appoint Expert  10-02-2008
# 9         1              10009  Receive Conclusion Expert  02-03-2008
#
#           Fin     resource     result type  value    agent  .order
# 0  01-01-2008     Client x        NaN  NaN    NaN      NaN    4907
# 1  09-01-2008     Client x        NaN  Car  600.0  Agent A    4908
# 2  13-01-2008  Assistant 1         OK  NaN    NaN      NaN    4909
# 3  13-01-2008  Assistant 1  By client  NaN    NaN      NaN    4910
# 4  15-01-2008  Assistant 1         OK  NaN    NaN      NaN    4911
# 5  20-01-2008    Manager 2        NaN  NaN    NaN      NaN    4912
# 6  01-02-2008  Assistant 1        NaN  NaN    NaN      NaN    4913
# 7  10-02-2008    Manager 2        NaN  NaN    NaN      NaN    4914
# 8  10-02-2008    Manager 2        NaN  NaN    NaN      NaN    4915
# 9  02-03-2008  Assistant 1        NaN  NaN    NaN      NaN    4916

# %%
fig, ax = plt.subplots(figsize=(7,4), tight_layout=True)
ax.hist(df['activity'],edgecolor = 'black',bins=14)
plt.xticks(rotation='vertical')
plt.ylabel("Number of declarations")
plt.xlabel("Number of activities")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
